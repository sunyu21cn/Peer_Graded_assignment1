# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Yu Sun**
# ----------
# Desired ocupation: Data Scientist

# %% [markdown]
# *I am interested in data science because I am curious about what story data can tell.*

# %% [markdown]
# ### The following code does a simple multiplication:

# %%
9*9
# Out:
# 81

# %% [markdown]
# 2022 olympic medal count
# ---
# 1. Norway
# 2. Germany
# 3. China
# 4. United States
#
# [2022 olympi medal count link](https://olympics.com/en/olympic-games/beijing-2022/medals)
#
# |Place          | Team          | Gold Medal number  |
# | ------------- |:-------------:| -----:             |
# | 1             | Norway        | 16                 |
# | 2             | Germany       | 12                 |
# | 3             | China         | 9                  |
# | 4             | United States | 8                  |
#
# `United States` is the country with the `most` olympic medals in the world.
